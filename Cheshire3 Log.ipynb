# %% [markdown]
# <p>
#     <h3>Search results for 'germany;':</h3>
#     harbinger:~$ cheshire3-search --database=db_ft germany<br/>
#     searched: cql.anywhere all "germany"<br/>
#     4 hits<br/>
#     1 recordStore/22843<br/>
#     2 recordStore/63685<br/>
#     3 recordStore/176606<br/>
#     4 recordStore/206786<br/>
# </p>

# %% [markdown]
# <p>
#     <h3>Search results for "dc.title any 'germany'":</h3>
# harbinger:~$ cheshire3-search --database=db_ft "dc.title any 'germany'"<br/>
# searched: dc.title any "'germany'"<br/>
# 0 hits<br/>
# </p>

# %% [markdown]
# <p>
#     <h3>Search results for "dc.title anywhere 'germany'":</h3>
# harbinger:~$ cheshire3-search --database=db_ft "dc.title anywhere 'germany'"<br/>
# Traceback (most recent call last):<br/>
#   File "/usr/bin/cheshire3-search", line 9, in <module><br/>
#     load_entry_point('cheshire3==1.0.11', 'console_scripts', 'cheshire3-search')()<br/>
#   File "/usr/lib/python2.7/site-packages/cheshire3/commands/cheshire3_search.py", line 68, in main<br/>
#     resultSet = db.search(session, query)<br/>
#   File "/usr/lib/python2.7/site-packages/cheshire3/database.py", line 291, in search<br/>
#     rs = self._search(session, query)<br/>
#   File "/usr/lib/python2.7/site-packages/cheshire3/database.py", line 231, in _search<br/>
#     rs = idx.search(session, query, self)<br/>
#   File "/usr/lib/python2.7/site-packages/cheshire3/index.py", line 692, in search<br/>
#     24)<br/>
# cheshire3.exceptions.QueryException: <class 'cheshire3.exceptions.QueryException'>: anywhere "'germany'"<br/>
# </p>

# %% [markdown]
# <span>
# zeerex_sru.xml
#
# <explain xmlns:c3="http://www.cheshire3.org/schemas/explain/" xmlns="http://explain.z3950.org/dtd/2.0/" authoritative="true" id="db_ft">
#   <serverInfo version="1.1" protocol="srw/u" transport="http">
#     <host>harbinger.ischool.berkeley.edu</host>
#     <port>80</port>
#     <database>api/sru/db_ft</database>
#   </serverInfo>
#   <databaseInfo>
#     <title></title>
#     <description></description>
#   </databaseInfo>
#   <metaInfo>
#     <dateModified>2013-04-15T06:34:41.341848</dateModified>
#   </metaInfo>
#   <schemaInfo/>
#   <indexInfo>
#     <set identifier="info:srw/cql-context-set/1/cql-v1.2" name="cql"/>
#     <set identifier="info:srw/cql-context-set/1/dc-v1.1" name="dc"/>
#     <set identifier="http://zing.z3950.org/cql/bath/2.0/" name="bath"/>
#
#     <index c3:index="idx-docno">
#       <title>Document Number</title>
#       <map>
# 	<name set="dc">identifier</name>
#       </map>
#       <configInfo>
#         <supports type="relation">exact</supports>
#         <supports type="relation">=</supports>
#         <supports type="relation">all</supports>
#         <supports type="relation">any</supports>
#         <supports type="relationModifier">word</supports>
#         <supports type="relationModifier">stem</supports>
#       </configInfo>
#     </index>
#
#     <index c3:index="idx-pauthor">
#       <title>Author</title>
#       <map>
# 	<name set="dc">creator</name>
#       </map>
#       <configInfo>
#         <supports type="relation">exact</supports>
#         <supports type="relation">=</supports>
#         <supports type="relation">all</supports>
#         <supports type="relation">any</supports>
#         <supports type="relationModifier">word</supports>
#       </configInfo>
#     </index>
# </span>

# %% [markdown]
# <span>
# <h3>config.xml:</h3>
#
# <config type="database" id="db_ft">
#   <objectType>cheshire3.database.SimpleDatabase</objectType>
#   <paths>
#     <path type="defaultPath">/home/cheshire3/cheshire3/dbs/ft</path>
#     <path type="metadataPath">.cheshire3/stores/metadata.bdb</path>
#     <object ref="recordStore" type="recordStore"/>
#     <object ref="cqlProtocolMap" type="protocolMap"/>
#     <path type="indexStoreList">indexStore</path>
#   </paths>
#   <subConfigs>
#     <subConfig type="recordStore" id="recordStore">
#       <objectType>cheshire3.recordStore.BdbRecordStore</objectType>
#       <paths>
#         <path type="defaultPath">.cheshire3/stores</path>
#         <path type="databasePath">recordStore.bdb</path>
#         <object ref="StringIntNormalizer" type="idNormalizer"/>
#       </paths>
#       <options>
#         <setting type="digest">md5</setting>
#       </options>
#     </subConfig>
#
#     <!-- indexStore -->
#     <subConfig type="indexStore" id="indexStore">
#       <objectType>cheshire3.indexStore.BdbIndexStore</objectType>
#       <paths>
#         <path type="defaultPath">.cheshire3/indexes</path>
#         <path type="tempPath">temp</path>
#         <path type="recordStoreHash">recordStore</path>
#       </paths>
#     </subConfig>
#
#     <subConfig type="workflow" id="indexIdList">
#       <objectType>cheshire3.workflow.CachingWorkflow</objectType>
#       <workflow>
#         <!--  input: list of record ids to process -->
#         <for-each>
#           <try>
#             <object type="recordStore" ref="recordStore" function="fetch_record"/>
#             <object type="database" function="index_record"/>
#           </try>
#           <except>
#             <break/>
#           </except>
#         </for-each>
#       </workflow>
#     </subConfig>
#     <!-- protocol map - a protocolMap maps contextual index name to actual object identifiers within the system -->
#     <subConfig type="protocolMap" id="cqlProtocolMap">
#       <objectType>cheshire3.protocolMap.CQLProtocolMap</objectType>
#       <paths>
#         <path type="zeerexPath">/home/cheshire3/cheshire3/dbs/ft/.cheshire3/zeerex_sru.xml</path>
#       </paths>
#     </subConfig>
#     <subConfig type="documentFactory" id="defaultDocumentFactory">
#       <objectType>cheshire3.documentFactory.SimpleDocumentFactory</objectType>
#       <options>
#         <setting type="filterRegexp">(\.([a-zA-Z0-9]+|tar.gz|tar.bz2)$|\d+_\d+$)</setting>
#         <default type="format">dir</default>
#         <default type="tagName">DOC</default>
#         <default type="cache">0</default>
#       </options>
#     </subConfig>
#     <path type="includeConfigs">/home/cheshire3/cheshire3/dbs/ft/.cheshire3/configSelectors.xml</path>
#     <path type="includeConfigs">/home/cheshire3/cheshire3/dbs/ft/.cheshire3/configIndexes.xml</path>
#
#     <!-- some custom normalizers we'll need later -->
#     <subConfig type="normalizer" id="AuthorStoplistNormalizer">
#       <objectType>cheshire3.normalizer.StoplistNormalizer</objectType>
#       <paths>
#         <!-- name of stoplist file -->
#         <path type="stoplist">stoplists/authorstoplist</path>
#       </paths>
#     </subConfig>
#
#     <subConfig type="normalizer" id="TitleStoplistNormalizer">
#       <objectType>cheshire3.normalizer.StoplistNormalizer</objectType>
#       <paths>
#         <path type="stoplist">stoplists/titlestoplist</path>
#       </paths>
#     </subConfig>
#
#     <subConfig type="normalizer" id="TopicStoplistNormalizer">
#       <objectType>cheshire3.normalizer.StoplistNormalizer</objectType>
#       <paths>
#         <path type="stoplist">stoplists/topicstoplist</path>
#       </paths>
#     </subConfig>
#
#     <subConfig type="normalizer" id="SubjectStoplistNormalizer">
#       <objectType>cheshire3.normalizer.StoplistNormalizer</objectType>
#       <paths>
#         <path type="stoplist">stoplists/subjstoplist</path>
#       </paths>
#     </subConfig>
#
#     <subConfig type="normalizer" id="FullStoplistNormalizer">
#       <objectType>cheshire3.normalizer.StoplistNormalizer</objectType>
#       <paths>
#         <path type="stoplist">stoplists/fullstoplist</path>
#       </paths>
#     </subConfig>
#
#     <subConfig type="normalizer" id="CountryStoplistNormalizer">
#       <objectType>cheshire3.normalizer.StoplistNormalizer</objectType>
#       <paths>
#         <path type="stoplist">stoplists/countrystoplist</path>
#       </paths>
#     </subConfig>
#
#     <!--
# The main indexes that I normally create for it are:
# Indexname	Containing tags   				normalization
# docno      	DOCNO             				keyword+lowercase
# pauthor    	BYLINE             				keyword+lowercase+stoplist
# title       HEADLINE       					keyword+lowercase +stoplist+ stemming
# topic       HEADLINE,DATELINE,BYLINE,TEXT   keyword+llowercase+stoplist+stemming
# all         DOC                    			keyword+lowercase+stoplist+stemming
# dateline    DATELINE        				keyword+lowercase+stoplist
# country    	DATELINE,CN  					keyword+lowercase+stoplist
# industries 	IN                         		keyword+lowercase
# types		TP                        		keyword+lowercase
# 	     -->
#
#     <!-- docno      	DOCNO             				keyword+lowercase -->
#     <subConfig type="index" id="idx-docno">
#       <objectType>cheshire3.index.SimpleIndex</objectType>
#       <paths>
#         <object type="indexStore" ref="indexStore" />
#       </paths>
#       <source>
#         <xpath>//DOCNO</xpath>
#         <process>
#           <!-- extract text from result of XPath evaluation -->
#           <object type="extractor" ref="SimpleExtractor" />
#           <!-- split on whitespace to create tokens -->
#           <object type="tokenizer" ref="SimpleTokenizer"/>
#           <!-- merge duplicates into unique keys, merge frequency, proximity etc. if present -->
#           <object type="tokenizer" ref="SimpleTokenMerger"/>
#           <!-- lowercases all keys -->
#           <object type="normalizer" ref="CaseNormalizer" />
#         </process>
#       </source>
#     </subConfig>
#
#     <!-- pauthor    	BYLINE             				keyword+lowercase+stoplist -->
#     <subConfig type="index" id="idx-pauthor">
#       <objectType>cheshire3.index.SimpleIndex</objectType>
#       <paths>
#         <object type="indexStore" ref="indexStore" />
#       </paths>
#       <source>
#         <xpath>//BYLINE</xpath>
#         <process>
#           <object type="extractor" ref="SimpleExtractor" />
#           <object type="tokenizer" ref="SimpleTokenizer"/>
#           <object type="tokenizer" ref="SimpleTokenMerger"/>
#           <object type="normalizer" ref="CaseNormalizer" />
#           <!--<object type="normalizer" ref="AuthorStoplistNormalizer" />-->
#         </process>
#       </source>
#     </subConfig>
#
#     <!-- title       HEADLINE       					keyword+lowercase +stoplist+ stemming -->
#     <subConfig type="index" id="idx-title">
#       <objectType>cheshire3.index.SimpleIndex</objectType>
#       <paths>
#         <object type="indexStore" ref="indexStore" />
#       </paths>
#       <source>
#         <xpath>//HEADLINE</xpath>
#         <process>
#           <object type="extractor" ref="SimpleExtractor" />
#           <object type="tokenizer" ref="SimpleTokenizer"/>
#           <object type="tokenizer" ref="SimpleTokenMerger"/>
#           <object type="normalizer" ref="CaseNormalizer" />
#           <!--<object type="normalizer" ref="TitleStoplistNormalizer" />-->
#           <object type="normalizer" ref="EnglishStemNormalizer" />
#         </process>
#       </source>
#     </subConfig>
#
#     <!-- topic       HEADLINE,DATELINE,BYLINE,TEXT		keyword+llowercase+stoplist+stemming -->
#     <subConfig type="index" id="idx-topic">
#       <objectType>cheshire3.index.SimpleIndex</objectType>
#       <paths>
#         <object type="indexStore" ref="indexStore" />
#       </paths>
#       <source>
#         <xpath>//HEADLINE</xpath>
#         <xpath>//DATELINE</xpath>
#         <xpath>//HBYLINE</xpath>
#         <xpath>//TEXT</xpath>
#         <process>
#           <object type="extractor" ref="SimpleExtractor" />
#           <object type="tokenizer" ref="SimpleTokenizer"/>
#           <object type="tokenizer" ref="SimpleTokenMerger"/>
#           <object type="normalizer" ref="CaseNormalizer" />
#           <!--<object type="normalizer" ref="TopicStoplistNormalizer" />-->
#           <object type="normalizer" ref="EnglishStemNormalizer" />
#         </process>
#       </source>
#     </subConfig>
#
#     <!-- all         DOC                    			keyword+lowercase+stoplist+stemming -->
#     <subConfig type="index" id="idx-all">
#       <objectType>cheshire3.index.SimpleIndex</objectType>
#       <paths>
#         <object type="indexStore" ref="indexStore" />
#       </paths>
#       <source>
#         <xpath>/DOC</xpath>
#         <process>
#           <object type="extractor" ref="SimpleExtractor" />
#           <object type="tokenizer" ref="SimpleTokenizer"/>
#           <object type="tokenizer" ref="SimpleTokenMerger"/>
#           <object type="normalizer" ref="CaseNormalizer" />
#           <!--<object type="normalizer" ref="FullStoplistNormalizer" />-->
#           <object type="normalizer" ref="EnglishStemNormalizer" />
#         </process>
#       </source>
#     </subConfig>
#
#     <!-- dateline    DATELINE        				keyword+lowercase+stoplist -->
#     <subConfig type="index" id="idx-dateline">
#       <objectType>cheshire3.index.SimpleIndex</objectType>
#       <paths>
#         <object type="indexStore" ref="indexStore" />
#       </paths>
#       <source>
#         <xpath>//DATELINE</xpath>
#         <process>
#           <object type="extractor" ref="SimpleExtractor" />
#           <object type="tokenizer" ref="SimpleTokenizer"/>
#           <object type="tokenizer" ref="SimpleTokenMerger"/>
#           <object type="normalizer" ref="CaseNormalizer" />
#           <!--<object type="normalizer" ref="TitleStoplistNormalizer" />-->
#         </process>
#       </source>
#     </subConfig>
#
#     <!-- country    	DATELINE,CN  					keyword+lowercase+stoplist -->
#     <subConfig type="index" id="idx-country">
#       <objectType>cheshire3.index.SimpleIndex</objectType>
#       <paths>
#         <object type="indexStore" ref="indexStore" />
#       </paths>
#       <source>
#         <xpath>//DATELINE</xpath>
#         <xpath>//CN</xpath>
#         <process>
#           <object type="extractor" ref="SimpleExtractor" />
#           <object type="tokenizer" ref="SimpleTokenizer"/>
#           <object type="tokenizer" ref="SimpleTokenMerger"/>
#           <object type="normalizer" ref="CaseNormalizer" />
#           <!--<object type="normalizer" ref="CountryStoplistNormalizer" />-->
#         </process>
#       </source>
#     </subConfig>
#
#     <!-- industries 	IN                         		keyword+lowercase -->
#     <subConfig type="index" id="idx-industries">
#       <objectType>cheshire3.index.SimpleIndex</objectType>
#       <paths>
#         <object type="indexStore" ref="indexStore" />
#       </paths>
#       <source>
#         <xpath>//IN</xpath>
#         <process>
#           <object type="extractor" ref="SimpleExtractor" />
#           <object type="tokenizer" ref="SimpleTokenizer"/>
#           <object type="tokenizer" ref="SimpleTokenMerger"/>
#           <object type="normalizer" ref="CaseNormalizer" />
#         </process>
#       </source>
#     </subConfig>
#
#     <!-- types		TP                        		keyword+lowercase -->
#     <subConfig type="index" id="idx-types">
#       <objectType>cheshire3.index.SimpleIndex</objectType>
#       <paths>
#         <object type="indexStore" ref="indexStore" />
#       </paths>
#       <source>
#         <xpath>//TP</xpath>
#         <process>
#           <object type="extractor" ref="SimpleExtractor" />
#           <object type="tokenizer" ref="SimpleTokenizer"/>
#           <object type="tokenizer" ref="SimpleTokenMerger"/>
#           <object type="normalizer" ref="CaseNormalizer" />
#         </process>
#       </source>
#     </subConfig>
#   </subConfigs>
# </config>
# </span>
